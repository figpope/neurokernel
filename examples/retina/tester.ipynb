# %%
import pycuda.driver as drv
import pycuda.autoinit
from pycuda.compiler import SourceModule
import numpy as np
mod = SourceModule("""
    #include <stdio.h>
    #include <curand.h>

    __global__ void tester(float* dest, float* src)
    {
      //printf("I am %d.%d\\n", threadIdx.x, threadIdx.y);
        const int i = threadIdx.x;
        int a[3] = {1,2,3};
        a[0] = 3;
        dest[i] = log2f(src[i]); 
    }
    """)
src = 3*np.ones((100,1),np.float32)
dest = np.ones((100,1),np.float32)
d = np.ones(2,np.int32)
grid = (int(d[0]),int(d[1]))
func = mod.get_function("tester")
func(drv.Out(dest), drv.In(src),
                    block=(100,1,1), grid=grid)
print dest
# Out:
# [[ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
#  [ 1.58496249]
# ...

# %%
a = np.ndarray((10,1),np.random)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-5789c62812b2> in <module>()
# ----> 1 a = np.ndarray((10,1),np.random())
#
# TypeError: 'module' object is not callable

# %%
a = np.random.rand(100)

# %%
a
# Out:
# array([ 0.6877776 ,  0.65907873,  0.31290147,  0.71145105,  0.98571015,
#         0.18197596,  0.51943902,  0.09998633,  0.11812619,  0.02519356,
#         0.09260664,  0.65978497,  0.46335667,  0.47055552,  0.83038906,
#         0.28573754,  0.92723446,  0.97198465,  0.09724113,  0.26701211,
#         0.524916  ,  0.11282103,  0.18313492,  0.56189047,  0.58303128,
#         0.59041851,  0.4630677 ,  0.32675902,  0.94394814,  0.98135118,
#         0.52590452,  0.33726018,  0.58393129,  0.84407457,  0.57184511,
#         0.60384873,  0.64705045,  0.9757793 ,  0.14169165,  0.31305194,
#         0.40102314,  0.43368652,  0.23057617,  0.42291023,  0.75879634,
#         0.87626263,  0.50838102,  0.93654665,  0.9932699 ,  0.80221621,
#         0.86568872,  0.60951431,  0.63400607,  0.73131428,  0.31062596,
#         0.70555537,  0.35383068,  0.10659198,  0.2845424 ,  0.89414392,
#         0.55105443,  0.62875718,  0.47971788,  0.75421606,  0.9294889 ,
# ...
