# %% [markdown]
# # Lamina LPU Configuration Demo

# %% [markdown]
# This notebook illustrates the configuration of the lamina LPU described in <a href="http://neurokernel.github.io/docs.html">Neurokernel RFC #2</a>: The Cartridge: A Canonical Neural Circuit Abstraction of the Lamina Neuropil - Construction and Composition Rules.

# %% [markdown]
# ### Specification of Neurons and Synapses

# %% [markdown]
# Assuming that the Neurokernel source has been cloned to ``~/neurokernel``, we first consider the two csv files that specify neurons and synapses in the lamina model.

# %%
# %cd -q ../examples/lamina2/data

# %% [markdown]
# The neuron model types and their parameter values are specified in the file ``neuron_type_lamina.csv``. The entire list of neurons is shown below. Note that for convenience, the LPU contains neurons from both the retina and lamina. Descriptions of each of the columns follow:
#
# * ``name`` - Name of neuron morphological type.
# * ``model`` - Specifies the name of the class implementing the neuron model.
# * ``columnar`` - A value of 1 in column indicates that the neuron/element is a columnar neuron/element; a number greater than 1 indicates the total number of non-columnar neurons of the specified ``name`` in the lamina.
# * ``dummy`` - Used to indicate alpha-profiles.
# * ``input`` - Indicates whether the neuron is an input axon from another LPU.
# * ``output`` - Indicates whether the neuron is an output neuron.
# * ``extern`` - Specifies if the neuron receives external input, e.g., a video signal.
# * ``public`` - Specifies if the neuron may communicate with other LPUs via Neurokernel's API.
#
# The remaining columns in the table are neuron model parameters.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
pd.set_option('display.max_columns', 20)
rcParams['figure.figsize'] = (17, 7)
neuron_data = pd.read_csv("./neuron_types_lamina.csv")
neuron_data = neuron_data.dropna(axis=1)
neuron_data.head(n=100)
# Out:
#    name          model  columnar  dummy  input  output  extern  public     V1  \
# 0    R1  Photoreceptor         1      0      1       0       1       0  0.000
# 1    R2  Photoreceptor         1      0      1       0       1       0  0.000
# 2    R3  Photoreceptor         1      0      1       0       1       0  0.000
# 3    R4  Photoreceptor         1      0      1       0       1       0  0.000
# 4    R5  Photoreceptor         1      0      1       0       1       0  0.000
# 5    R6  Photoreceptor         1      0      1       0       1       0  0.000
# 6    L1    MorrisLecar         1      0      0       1       0       1 -0.001
# 7    L2    MorrisLecar         1      0      0       1       0       1 -0.001
# 8    L3    MorrisLecar         1      0      0       1       0       1 -0.001
# 9    L4    MorrisLecar         1      0      0       1       0       1 -0.001
# 10   L5    MorrisLecar         1      0      0       1       0       1 -0.001
# 11   T1    MorrisLecar         1      0      0       1       0       1 -0.001
# 12   C2    MorrisLecar         1      0      0       1       0       1 -0.001
# 13   C3    MorrisLecar         1      0      0       1       0       1 -0.001
# 14   Am    MorrisLecar       350      0      0       0       0       0 -0.001
# 15   a1    MorrisLecar         1      1      0       0       0       0 -0.001
# 16   a2    MorrisLecar         1      1      0       0       0       0 -0.001
# 17   a3    MorrisLecar         1      1      0       0       0       0 -0.001
# 18   a4    MorrisLecar         1      1      0       0       0       0 -0.001
# 19   a5    MorrisLecar         1      1      0       0       0       0 -0.001
# 20   a6    MorrisLecar         1      1      0       0       0       0 -0.001
#
#        V2    V3     V4     phi    initV   initn  offset      sa      si  \
# 0   0.000  0.00  0.000  0.0000 -0.07000  0.0000    0.00  0.3664  0.8969
# 1   0.000  0.00  0.000  0.0000 -0.07000  0.0000    0.00  0.3664  0.8969
# 2   0.000  0.00  0.000  0.0000 -0.07000  0.0000    0.00  0.3664  0.8969
# 3   0.000  0.00  0.000  0.0000 -0.07000  0.0000    0.00  0.3664  0.8969
# 4   0.000  0.00  0.000  0.0000 -0.07000  0.0000    0.00  0.3664  0.8969
# 5   0.000  0.00  0.000  0.0000 -0.07000  0.0000    0.00  0.3664  0.8969
# 6   0.015 -0.05  0.001  0.0025 -0.05000  0.5000    0.02  0.0000  0.0000
# 7   0.015 -0.05  0.001  0.0025 -0.05000  0.5000    0.02  0.0000  0.0000
# 8   0.015 -0.05  0.001  0.0025 -0.05000  0.5000    0.02  0.0000  0.0000
# 9   0.015 -0.05  0.001  0.0025 -0.05000  0.5000    0.02  0.0000  0.0000
# 10  0.015 -0.05  0.001  0.0025 -0.05000  0.5000    0.02  0.0000  0.0000
# 11  0.015 -0.05  0.001  0.0025 -0.05000  0.5000    0.02  0.0000  0.0000
# 12  0.015 -0.05  0.001  0.0025 -0.05000  0.5000    0.02  0.0000  0.0000
# 13  0.015 -0.05  0.001  0.0025 -0.05000  0.5000    0.02  0.0000  0.0000
# 14  0.015  0.00  0.030  0.2000 -0.05184  0.0306    0.00  0.0000  0.0000
# 15  0.015 -0.05  0.001  0.0025  0.00000  0.0000    0.00  0.0000  0.0000
# 16  0.015 -0.05  0.001  0.0025  0.00000  0.0000    0.00  0.0000  0.0000
# 17  0.015 -0.05  0.001  0.0025  0.00000  0.0000    0.00  0.0000  0.0000
# 18  0.015 -0.05  0.001  0.0025  0.00000  0.0000    0.00  0.0000  0.0000
# 19  0.015 -0.05  0.001  0.0025  0.00000  0.0000    0.00  0.0000  0.0000
# 20  0.015 -0.05  0.001  0.0025  0.00000  0.0000    0.00  0.0000  0.0000
#
#       dra     dri
# 0   0.027  0.4092
# 1   0.027  0.4092
# 2   0.027  0.4092
# 3   0.027  0.4092
# 4   0.027  0.4092
# 5   0.027  0.4092
# 6   0.000  0.0000
# 7   0.000  0.0000
# 8   0.000  0.0000
# 9   0.000  0.0000
# 10  0.000  0.0000
# 11  0.000  0.0000
# 12  0.000  0.0000
# 13  0.000  0.0000
# 14  0.000  0.0000
# 15  0.000  0.0000
# 16  0.000  0.0000
# 17  0.000  0.0000
# 18  0.000  0.0000
# 19  0.000  0.0000
# 20  0.000  0.0000
#
# [21 rows x 20 columns]

# %% [markdown]
# The synaptic connection attributes inside a cartridge and those specified by Composition Rule II are loaded from the csv file ``synapse_lamina.csv``. A few examples are listed below. Descriptions of each of the columns follow:
#
# * ``prename``, ``postname`` - Indicate the neurons connected by the synapse.
# * ``model`` - Indicates the synapse model used in the LPU.
# * ``cart`` - Specifies the relative position from the cartridge of the presynaptic neuron to that of the postsynaptic neuron (see In [6] below).
# * ``mode`` - indicates if the synapse affects the neurotransmitter release at the axon terminals of the postsynaptic neuron.
# * ``scale`` is the number of synapses between the pre- and post-synaptic neurons.
#
# The remaining columns are synapse model parameters.

# %%
synapse_data = pd.read_csv("./synapse_lamina.csv")
synapse_data = synapse_data.dropna(axis=1)
synapse_data.head(n=7)
# Out:
#   prename postname            model  cart  reverse  delay  threshold  slope  \
# 0      R1       L1  power_gpot_gpot     0    -0.08      1   -0.05214   0.02
# 1      R1       L2  power_gpot_gpot     0    -0.08      1   -0.05214   0.02
# 2      L2       L4  power_gpot_gpot     2     0.00      1   -0.05050   2.00
# 3      L2       L4  power_gpot_gpot     3     0.00      1   -0.05050   2.00
# 4      L4       R1  power_gpot_gpot     5     0.00      1   -0.05050   2.00
# 5      L4       L4  power_gpot_gpot     4     0.00      1   -0.05050   2.00
# 6      L4       L5  power_gpot_gpot     6     0.00      1   -0.05050   0.50
#
#    power  saturation  scale  mode
# 0      1      0.0008     40     0
# 1      1      0.0008     40     0
# 2      1      0.0300      4     0
# 3      1      0.0300      2     0
# 4      1      0.1000      1     1
# 5      1      0.0500      2     0
# 6      1      0.1000      1     0
#
# [7 rows x 12 columns]

# %% [markdown]
# To change the lamina circuitry, rows may be added, deleted, or modified in both csv files.
# These files are processed by the ``generate_lamina_gexf.py`` script to generate a GEXF file containing the full lamina configuration comprising 768 cartridges; this file may be used to instantiate the lamina LPU using Neurokernel.

# %%
# %run generate_lamina_gexf.py

# %% [markdown]
# The next section describes the steps in the generation of an LPU configuration using the data in the csv files described above.

# %% [markdown]
# ### Generation of Lamina Configuration and Creating GEXF

# %% [markdown]
# We first generate a lamina configuration model using the above two csv files, for a total of 24$\times$32=768 cartridges, where 24 is the number of rows and 32 is the number of columns for a hexagonal array. The hexagonal array is shown below.

# %%
import vision_configuration as vc
lamina = vc.Lamina(12, 16, 'neuron_types_lamina.csv', 'synapse_lamina.csv', None)
print lamina.num_cartridges
# Out:
# 192

# %%
figure(figsize=(15,7))
X = lamina.hexarray.X
Y = lamina.hexarray.Y
plot(X.reshape(-1), Y.reshape(-1), 'o', markerfacecolor = 'w', 
    markeredgecolor = 'b', markersize = 12)
axis('equal')
axis([X.min()-1, X.max()+1, Y.min()-1, Y.max()+1])
xlabel('x (arbitrary unit)')
ylabel('y (arbitrary unit)')
gca().invert_yaxis()

# label one cartridge position
center_row = 12
center_col = 16
plot(X[center_row, center_col], Y[center_row, center_col], 
       marker = '$0$', markeredgecolor = 'r', hold = True) 

# find and label all its neighbors, the numbers are used for 
# column 'cart' in the synapse_lamina.csv
neighbors = lamina.hexarray.find_neighbor(center_row, center_col)
for neighbor, i in zip(neighbors[1:], range(1,7)):
    if neighbor is not None:
        neighbor_row = lamina.hexarray.row[neighbor]
        neighbor_col = lamina.hexarray.col[neighbor]
        plot(X[neighbor_row, neighbor_col], Y [neighbor_row, neighbor_col], 
               marker = '$'+str(i)+'$', markeredgecolor = 'r', hold = True) 
    
tx1 = text(50, 10, 'Anterior', fontsize=12)
ar1 = arrow(60, 9.5, -3, 0, head_width = 1, color = 'k')
tx2 = text(58, 4, 'Dorsal', fontsize = 12)
ar2 = arrow(60, 9.5, 0, -3, head_width = 1, color = 'k')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-12b5dd5ccc4c> in <module>()
#      13 center_row = 12
#      14 center_col = 16
# ---> 15 plot(X[center_row, center_col], Y[center_row, center_col],
#      16        marker = '$0$', markeredgecolor = 'r', hold = True)
#      17
#
# IndexError: index 12 is out of bounds for axis 0 with size 12

# %% [markdown]
# We now create all the cartridges. Each cartridge contains one copy of all specified columnar neurons and elements as well as all the intra-cartridge connections. Individual neurons and synapses in each cartridge can be accessed as follows:

# %%
lamina.create_cartridges()
lamina.cartridges[100]
# Out:
# Isolated cartridge at 0x38742510

# %%
lamina.cartridges[100].neurons['L2']
# Out:
# neuron L2: {'phi': 0.0025, 'initn': 0.5, 'output': 1, 'offset': 0.02, 'extern': 0, 'spiking': False, 'model': 'MorrisLecar', 'dummy': 0, 'name': 'L2', 'V1': -0.001, 'V2': 0.015, 'dri': 0.0, 'initV': -0.05, 'si': 0.0, 'V3': -0.05, 'V4': 0.001, 'dra': 0.0, 'input': 0, 'sa': 0.0, 'columnar': 1, 'public': 1}

# %%
lamina.cartridges[100].synapses[8]
# Out:
# synapse from R3 to L2: {'slope': 0.02, 'saturation': 0.0008, 'postname': 'L2', 'reverse': -0.08, 'power': 1.0, 'cart': 0, 'delay': 1.0, 'prename': 'R3', 'conductance': True, 'scale': 37.0, 'mode': 0, 'threshold': -0.05214, 'model': 'power_gpot_gpot', 'class': 1}

# %% [markdown]
# We assign each cartridge to a position on the hexagonal grid and link it to its 6 immediate neighbor cartridges; the first element of the ``neighbors`` attribute is the cartridge itself, while the remaining 6 elements are its neighbors:

# %%
lamina.connect_cartridges()
lamina.cartridges[100].neighbors
# Out:
# [Cartridge at (6.0, 10.392304845413264),
#  Cartridge at (6.0, 8.660254037844386),
#  Cartridge at (4.5, 9.526279441628825),
#  Cartridge at (4.5, 11.258330249197703),
#  Cartridge at (6.0, 12.12435565298214),
#  Cartridge at (7.5, 11.258330249197703),
#  Cartridge at (7.5, 9.526279441628825)]

# %% [markdown]
# The non-columnar neurons are created as follows:

# %%
lamina.create_non_columnar_neurons()

# %% [markdown]
# After all the cartridges and non-columnar neurons are created, we can specify interconnects between cartridges based on the composition rules. We first configure inter-cartridge synapses based on Composition Rule II:

# %%
lamina.connect_composition_II()

# %% [markdown]
# In the example below, the L4 neuron in cartridge 100 (shown as a red dot), receives inputs (green lines) from neurons in some neighboring cartridges (green dots), and provides outputs (blue lines) to neurons in other neighboring cartridges (blue dots):

# %%
figure(figsize=(15,7))
plot(X.reshape(-1), Y.reshape(-1), 'o', markerfacecolor = 'w', 
     markeredgecolor = 'b', markersize = 10)
axis('equal')
axis([X.min()-1, X.max()+1, Y.min()-1, Y.max()+1])
gca().invert_yaxis()

# plot the position of L4 neuron in cartridge 100
neuron = lamina.cartridges[204+32].neurons['L4']
x, y = neuron.position()
plot(x, y, 'o', markerfacecolor = 'r', markersize = 10, hold = True)

# plot the positions of the neuron the L4 neuron is presynaptic to
for synapse in neuron.outgoing_synapses:
    post_x, post_y = synapse.post_neuron.position()
    plot(post_x+0.1, post_y+0.1, 'o', markerfacecolor = 'b', markersize = 3, hold = True)
    plot([x, post_x+0.1], [y, post_y+0.1], 'b', hold = True)

# plot the positions of the neuron the L4 neuron is postsynaptic to
for synapse in neuron.incoming_synapses:
    pre_x, pre_y = synapse.pre_neuron.position()
    plot(pre_x-0.1, pre_y-0.1, 'o', markerfacecolor = 'g', markersize = 3, hold = True)
    plot([x, pre_x-0.1], [y, pre_y-0.1], 'g', hold = True)
    
xlabel('x (arbitrary unit)')
ylabel('y (arbitrary unit)')
tx1 = text(50, 10, 'Anterior', fontsize=12)
ar1 = arrow(60, 9.5, -3, 0, head_width = 1, color = 'k')
tx2 = text(58, 4, 'Dorsal', fontsize = 12)
ar2 = arrow(60, 9.5, 0, -3, head_width = 1, color = 'k')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-6ad7b79fb8ff> in <module>()
#       7
#       8 # plot the position of L4 neuron in cartridge 100
# ----> 9 neuron = lamina.cartridges[204+32].neurons['L4']
#      10 x, y = neuron.position()
#      11 plot(x, y, 'o', markerfacecolor = 'r', markersize = 10, hold = True)
#
# IndexError: list index out of range

# %% [markdown]
# We then configure inter-cartridge synapses based on Composition Rule I:

# %%
lamina.connect_composition_I()

# %% [markdown]
# In the example below, amacrine cell 0 (red dot) receives inputs (green lines) from neurons in several neighboring cartridges (green dots), and provides outputs (blue lines) to neurons in other neighboring cartridges (blue dots):

# %%
figure(figsize = (15,7))
plot(X.reshape(-1), Y.reshape(-1), 'o', markerfacecolor = 'w', 
     markeredgecolor = 'b', markersize = 10)
axis('equal')
axis([X.min()-1, X.max()+1, Y.min()-1, Y.max()+1])
gca().invert_yaxis()

# plot the position of Amacrine cell 0
neuron = lamina.non_columnar_neurons[240]
x, y = neuron.position()
plot(x, y, 'o', markerfacecolor = 'r', markersize = 10, hold = True)

# plot the positions of the neuron the Am 0 is presynaptic to
for synapse in neuron.outgoing_synapses:
    post_x, post_y = synapse.post_neuron.position()
    plot(post_x+0.1, post_y+0.1, 'o', markerfacecolor = 'b', markersize = 3, hold = True)
    plot([x, post_x+0.1], [y, post_y+0.1], 'b', hold = True)
# plot the positions of the neuron the Am 0 is postsynaptic to
for synapse in neuron.incoming_synapses:
    pre_x, pre_y = synapse.pre_neuron.position()
    plot(pre_x-0.1, pre_y-0.1, 'o', markerfacecolor = 'g', markersize = 3, hold = True)
    plot([x, pre_x-0.1], [y, pre_y-0.1], 'g', hold = True)

xlabel('x (arbitrary unit)')
ylabel('y (arbitrary unit)')
tx1 = text(50, 10, 'Anterior', fontsize=12)
ar1 = arrow(60, 9.5, -3, 0, head_width = 1, color = 'k')
tx2 = text(58, 4, 'Dorsal', fontsize = 12)
ar2 = arrow(60, 9.5, 0, -3, head_width = 1, color = 'k')

# %% [markdown]
# Finally, we output the full configuration to GEXF file format that can be used to instantiate the lamina LPU:

# %%
lamina.export_to_gexf('lamina.gexf.gz')

# %% [markdown]
# ### Executing the Model

# %% [markdown]
# We first generate an input of duration 1.0 second and then execute the model:

# %%
# %run gen_vis_input.py

# %%
# %cd -q ~/NK/neurokernel/examples/lamina2/
# %run lamina_demo.py
# Out:
# 1152
# 30067932160
# [-0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0.07, -0 ...
# [-0.07 -0.07 -0.07 ..., -0.07 -0.07 -0.07]
# Process LPU-2:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/hanyu/NK/local/lib/python2.7/site-packages/neurokernel-0.1-py2.7.egg/neurokernel/core.py", line 776, in run
#     self.pre_run()
#   File "/home/hanyu/NK/local/lib/python2.7/site-packages/neurokernel-0.1-py2.7.egg/neurokernel/LPU/LPU.py", line 263, in pre_run
#     self._init_objects()
#   File "/home/hanyu/NK/local/lib/python2.7/site-packages/neurokernel-0.1-py2.7.egg/neurokernel/LPU/LPU.py", line 381, in _init_objects
#     self.neurons = [ self._instantiate_neuron(i,t,n) for i,(t,n) in enumerate(self.n_list) ]
#   File "/home/hanyu/NK/local/lib/python2.7/site-packages/neurokernel-0.1-py2.7.egg/neurokernel/LPU/LPU.py", line 811, in _instantiate_neuron
#     self.dt, debug=self.debug, LPU_id=self.id)
#   File "/home/hanyu/NK/local/lib/python2.7/site-packages/neurokernel-0.1-py2.7.egg/neurokernel/LPU/neurons/Photoreceptor.py", line 37, in __init__
#     cuda.memcpy_htod(int(self.V), np.asarray(n_dict['initV'], dtype=np.double))
# LogicError: cuMemcpyHtoD failed: invalid value

# %% [markdown]
# Next, we generate a video of the membrane potentials of specific neurons:

# %%
# %run visualize_output.py
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/hanyu/NK/local/lib/python2.7/site-packages/IPython/utils/py3compat.pyc in execfile(fname, *where)
#     202             else:
#     203                 filename = fname
# --> 204             __builtin__.execfile(filename, *where)
#
# /home/hanyu/NK/neurokernel/examples/lamina2/visualize_output.py in <module>()
#      67 V.codec = 'libtheora'
#      68 V.dt = 0.0001
# ---> 69 V.run()
#      70
#
# /home/hanyu/NK/local/lib/python2.7/site-packages/neurokernel-0.1-py2.7.egg/neurokernel/LPU/utils/visualizer.pyc in run(self, final_frame_name, dpi)
#     144         '''
#     145
# --> 146         self._initialize()
#     147         if not self._update_interval:
#     148             self._update_interval = self._maxt - 1
#
# /home/hanyu/NK/local/lib/python2.7/site-packages/neurokernel-0.1-py2.7.egg/neurokernel/LPU/utils/visualizer.pyc in _initialize(self)
#     259                     else:
#     260                         temp = self.axarr[ind].imshow(np.reshape(\
# --> 261                                 self._data[LPU][config['ids'][0],0], config['shape']))
#     262
#     263
#
# /home/hanyu/NK/local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in reshape(a, newshape, order)
#     216     except AttributeError:
#     217         return _wrapit(a, 'reshape', newshape, order=order)
# --> 218     return reshape(newshape, order=order)
#     219
#     220
#
# ValueError: total size of new array must be unchanged

# %% [markdown]
# The visualization script produces a video that depicts an input video signal provided to the retina and the responses of R1, L1, L2, L3 and L4 neurons in all the cartridges. Each pixel in the visualization corresponds to the neuron associated with one cartridge.

# %%
import IPython.display
IPython.display.YouTubeVideo('QDVoro2GhAU')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/QDVoro2GhAU"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
